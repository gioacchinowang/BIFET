# %% [markdown]
# # BIFET verification example_light_DEL
#
# In example DEL
#
# we propose a spatial diffusion + energy loss problem
#
# which merges emxaple_light_Dxx and example_light_EL into one problem

# %% [markdown]
# ## 1. time-independent solver

# %% [markdown]
# #### spatial domain err

# %%
# %pylab inline
import matplotlib.pyplot as plt

# dim 1+1
# refine global
# pol. 1
ex_1d_rg1 = array(matrix('0    0.0227861;\
1    0.00581554;\
2    0.00145486;\
3    0.000363903;\
4    9.11236e-05'))

# dim 1+1
# refine adaptive
# pol. 1
ex_1d_ra1 = array(matrix('0    0.0227861;\
1    0.00581554;\
2    0.00145467;\
3    0.00115923;\
4    0.000328303'))

# dim 1+1
# refine global
# pol. 2
ex_1d_rg2 = array(matrix('0    0.00218009;\
1    0.000251803;\
2    3.18783e-05;\
3    4.05412e-06;\
4    5.11922e-07'))

# error list copied from Dxxtrial output

# dim 2+1
# refine global
# pol. 1
ex_2d_rg1 = array(matrix('0    0.0146286;\
1    0.00378423;\
2    0.000972062;\
3    0.000249398;\
4    6.36372e-05'))

# dim 2+1
# refine adaptive
# pol. 1
ex_2d_ra1 = array(matrix('0    0.0146286;\
1    0.00378423;\
2    0.00108067;\
3    0.000763627;\
4    0.000225698'))

# dim 1+1
# refine global
# pol. 2
ex_2d_rg2 = array(matrix('0    0.00149288;\
1    0.000173237;\
2    2.22821e-05;\
3    2.95118e-06;\
4    3.84503e-07'))

ex_3d_rg1 = array(matrix('0    0.0100188;\
1    0.00256723;\
2    0.000660185;\
3    0.000170859;\
4    4.352956e-05'))

ex_3d_ra1 = array(matrix('0    0.0100188;\
1    0.00256723;\
2    0.000763345;\
3    0.000487882;\
4    0.000153568'))

fig1, ax1 = plt.subplots(figsize=(9,9))

ylim = (2.e-7,0.05)


g1 = ax1.plot(2**(ex_1d_rg1[:,0]+1),ex_1d_rg1[:,1],
              marker='o',markersize=6,c='steelblue',linewidth=4,
              label='$\mathbb{R}^{1+1}$, global, pol.1')
g2 = ax1.plot(2**(ex_2d_rg1[:,0]+1),ex_2d_rg1[:,1],
              marker='o',markersize=6,c='firebrick',linewidth=4,
              label='$\mathbb{R}^{2+1}$, global, pol.1')
g3 = ax1.plot(2**(ex_3d_rg1[:,0]+1),ex_3d_rg1[:,1],
              marker='o',markersize=6,c='darkseagreen',linewidth=4,
              label='$\mathbb{R}^{3+1}$, global, pol.1')

g12 = ax1.plot(2**(ex_1d_rg2[:,0]+1),ex_1d_rg2[:,1],
               marker='o',markersize=6,c='steelblue',linewidth=4,linestyle='-.',
               label='$\mathbb{R}^{1+1}$, global, pol.2')
g22 = ax1.plot(2**(ex_2d_rg2[:,0]+1),ex_2d_rg2[:,1],
               marker='o',markersize=6,c='firebrick',linewidth=4,linestyle='-.',
               label='$\mathbb{R}^{2+1}$, global, pol.2')

a1 = ax1.plot(2**(ex_1d_ra1[:,0]+1),ex_1d_ra1[:,1],
              marker='o',markersize=6,c='steelblue',linewidth=4,linestyle='--',
              label='$\mathbb{R}^{1+1}$, adaptive, pol.1')
a2 = ax1.plot(2**(ex_2d_ra1[:,0]+1),ex_2d_ra1[:,1],
              marker='o',markersize=6,c='firebrick',linewidth=4,linestyle='--',
              label='$\mathbb{R}^{2+1}$, adaptive, pol.1')
a3 = ax1.plot(2**(ex_3d_ra1[:,0]+1),ex_3d_ra1[:,1],
              marker='o',markersize=6,c='darkseagreen',linewidth=4,linestyle='--',
              label='$\mathbb{R}^{3+1}$, adaptive, pol.1')

x0 = linspace(1,300,20)
l1 = ax1.plot(x0,0.05/x0**1,color='k',linestyle=':',linewidth=2,label=r'$h^{1}$ scaling')
l2 = ax1.plot(x0,0.05/x0**2,color='k',linestyle='--',linewidth=2,label=r'$h^{2}$ scaling')
l3 = ax1.plot(x0,0.05/x0**3,color='k',linestyle='-.',linewidth=2,label=r'$h^{3}$ scaling')

ax1.set_xscale("log", nonposx='clip')
ax1.set_yscale("log", nonposy='clip')

lgd = ax1.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=20)
ax1.set_xlim((1,50))
ax1.set_ylim(ylim)
ax1.set_xlabel(r'$L/h$ (fixed $L$)',fontsize='20')
ax1.set_ylabel(r'$\epsilon_{\mathrm{L}^2,\mathbf{q}}$',fontsize='20')
ax1.tick_params(axis='both', which='major', labelsize='20')

#fig1.tight_layout()

savefig('DEL_err1.pdf', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### spectral domain err

# %%
# %pylab inline
import matplotlib.pyplot as plt

# dim 1+1
# refine global
# pol. 1
eq_1d_rg1 = array(matrix('0    0.0177245;\
1    0.0050665;\
2    0.00131444;\
3    0.000333218;\
4    8.38934e-05'))

# dim 1+1
# refine adaptive
# pol. 1
eq_1d_ra1 = array(matrix('0    0.0177245;\
1    0.0050665;\
2    0.00141387;\
3    0.000559437;\
4    0.000287539'))

# dim 1+1
# refine global
# pol. 2
eq_1d_rg2 = array(matrix('0    0.00168405;\
1    0.000251283;\
2    3.41266e-05;\
3    4.40741e-06;\
4    5.58617e-07'))

# dim 1+2
eq_2d_rg1 = array(matrix('0       0.0043848;\
1       0.00120047;\
2       0.000306691;\
3       7.76836e-05;\
4       1.96007e-05'))

# dim 1+2
eq_2d_ra1 = array(matrix('0       0.0043848;\
1       0.00121582;\
2       0.000364586;\
3       0.000143914;\
4       6.18392e-05'))

# dim 1+2
eq_2d_rg2 = array(matrix('0       0.000397641;\
1       5.70094e-05;\
2       7.82004e-06;\
3       1.02129e-06;\
4       1.30327e-07'))

eq_3d_ra1 = array(matrix('0    0.000911373;\
1    0.0002428;\
2    6.38865e-05;\
3    1.98378e-05;\
4    6.37505e-06'))

eq_3d_rg1 = array(matrix('0    0.000911373;\
1    0.000242674;\
2    6.14009e-05;\
3    1.53457e-5;\
4    3.94752e-6'))


fig1, ax1 = plt.subplots(figsize=(9,9))

ylim = (2.e-7,0.05)

g1 = ax1.plot(2**(eq_1d_rg1[:,0]+1),eq_1d_rg1[:,1],
              marker='o',markersize=6,c='steelblue',linewidth=4,
              label='$\mathbb{R}^{1+1}$, global, pol.1')
g2 = ax1.plot(2**(eq_2d_rg1[:,0]+1),eq_2d_rg1[:,1],
              marker='o',markersize=6,c='firebrick',linewidth=4,
              label='$\mathbb{R}^{1+2}$, global, pol.1')
g3 = ax1.plot(2**(eq_3d_rg1[:,0]+1),eq_3d_rg1[:,1],
              marker='o',markersize=6,c='darkseagreen',linewidth=4,
              label='$\mathbb{R}^{1+3}$, global, pol.1')

g12 = ax1.plot(2**(eq_1d_rg2[:,0]+1),eq_1d_rg2[:,1],
               marker='o',markersize=6,c='steelblue',linewidth=4,linestyle='-.',
               label='$\mathbb{R}^{1+1}$, global, pol.2')
g22 = ax1.plot(2**(eq_2d_rg2[:,0]+1),eq_2d_rg2[:,1],
               marker='o',markersize=6,c='firebrick',linewidth=4,linestyle='-.',
               label='$\mathbb{R}^{1+2}$, global, pol.2')

a1 = ax1.plot(2**(eq_1d_ra1[:,0]+1),eq_1d_ra1[:,1],
              marker='o',markersize=6,c='steelblue',linewidth=4,linestyle='--',
              label='$\mathbb{R}^{1+1}$, adaptive, pol.1')
a1 = ax1.plot(2**(eq_2d_ra1[:,0]+1),eq_2d_ra1[:,1],
              marker='o',markersize=6,c='firebrick',linewidth=4,linestyle='--',
              label='$\mathbb{R}^{1+2}$, adaptive, pol.1')
a3 = ax1.plot(2**(eq_3d_ra1[:,0]+1),eq_3d_ra1[:,1],
              marker='o',markersize=6,c='darkseagreen',linewidth=4,linestyle='--',
              label='$\mathbb{R}^{1+3}$, adaptive, pol.1')

x0 = linspace(1,300,20)
l1 = ax1.plot(x0,0.05/x0**1,color='k',linestyle=':',linewidth=2,label=r'$h^{1}$ scaling')
l2 = ax1.plot(x0,0.05/x0**2,color='k',linestyle='--',linewidth=2,label=r'$h^{2}$ scaling')
l3 = ax1.plot(x0,0.05/x0**3,color='k',linestyle='-.',linewidth=2,label=r'$h^{3}$ scaling')

ax1.set_xscale("log", nonposx='clip')
ax1.set_yscale("log", nonposy='clip')

lgd = ax1.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=20)
ax1.set_xlim((1,50))
ax1.set_ylim(ylim)
ax1.set_xlabel(r'$L/h$ (fixed $L$)',fontsize='20')
ax1.set_ylabel(r'$\epsilon_{\mathrm{L}^2,\mathbf{x}}$',fontsize='20')
ax1.tick_params(axis='both', which='major', labelsize='20')

#fig1.tight_layout()

savefig('DEL_err2.pdf', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/jiaxin/lab/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['ylim']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ## 2. time-dependent solver

# %% [markdown]
# #### spatial domain fixed time difference (evolution check)

# %%
# %pylab inline
import matplotlib.pyplot as plt

# SPATIAL
threads = linspace(1,20,num=20)

err_lv0 = array(matrix('10	0.484401;\
60	0.25889;\
110	0.134446;\
160	0.0655061;\
210	0.0275212;\
260	0.00859858;\
310	0.00964222;\
360	0.015093;\
410	0.0184715;\
460	0.0203943;\
510	0.0214683;\
560	0.0220633;\
610	0.0223911;\
660	0.022571;\
710	0.0226693;\
760	0.0227229;\
810	0.022752;\
860	0.0227677;\
910	0.0227762;\
960	0.0227808;\
1010	0.0227833;\
1060	0.0227846;\
1860	0.000363902;\
1910	0.000363903;\
1960	0.000363903;\
2010	0.000363903;\
2060	0.000363903'))

err_lv4 = array(matrix('10	0.783273;\
60	0.47416;\
110	0.290424;\
160	0.177807;\
210	0.108811;\
260	0.0665563;\
310	0.0406872;\
360	0.0248543;\
410	0.0151664;\
460	0.00923978;\
510	0.00561491;\
560	0.00339824;\
610	0.00204295;\
660	0.00121445;\
710	0.000708103;\
760	0.000398845;\
810	0.000210297;\
860	9.62129e-05;\
910	3.2365e-05;\
960	3.08121e-05;\
1010	5.21378e-05;\
1060	6.69195e-05;\
1110	7.62411e-05;\
1160	8.20425e-05;\
1210	8.56147e-05;\
1260	8.77756e-05;\
1310	8.90627e-05;\
1360	8.98321e-05;\
1410	9.03068e-05;\
1460	9.06129e-05;\
1510	9.08153e-05;\
1560	9.09476e-05;\
1610	9.10301e-05;\
1660	9.1078e-05;\
1710	9.11035e-05;\
1760	9.11158e-05;\
1810	9.1121e-05;\
1860	9.1123e-05;\
1910	9.11236e-05;\
1960	9.11237e-05;\
2010	9.11237e-05;\
2060	9.11236e-05'))

e_1d_rg1 = array(matrix('0    0.0227861;\
1    0.00581554;\
2    0.00145486;\
3    0.000363903;\
4    9.11236e-05'))

print (2**(e_1d_rg1[:,1]+1))

fig1, ax1 = plt.subplots(figsize=(9,9))

l0 = ax1.plot((0,2000),(e_1d_rg1[0,1],e_1d_rg1[0,1]),color='grey',linestyle='--',linewidth=2)
l1 = ax1.plot((0,2000),(e_1d_rg1[1,1],e_1d_rg1[1,1]),color='grey',linestyle='--',linewidth=2)
l2 = ax1.plot((0,2000),(e_1d_rg1[2,1],e_1d_rg1[2,1]),color='grey',linestyle='--',linewidth=2)
l3 = ax1.plot((0,2000),(e_1d_rg1[3,1],e_1d_rg1[3,1]),color='grey',linestyle='--',linewidth=2)
l4 = ax1.plot((0,2000),(e_1d_rg1[4,1],e_1d_rg1[4,1]),color='grey',linestyle='--',linewidth=2)

c0 = ax1.plot (err_lv0[:,0],err_lv0[:,1],
               marker='X',markersize=10,c='steelblue',linewidth=3,
               label=r'$L/h = 2$')
c1 = ax1.plot (err_lv1[:,0],err_lv1[:,1],
               marker='o',markersize=10,c='firebrick',linewidth=3,
               label=r'$L/h = 4$')
c2 = ax1.plot (err_lv2[:,0],err_lv2[:,1],
               marker='s',markersize=10,c='darkseagreen',linewidth=3,
               label=r'$L/h = 8$')
c3 = ax1.plot (err_lv3[:,0],err_lv3[:,1],
               marker='d',markersize=10,c='darkorange',linewidth=3,
               label=r'$L/h = 16$')
c4 = ax1.plot (err_lv4[:,0],err_lv4[:,1],
               marker='*',markersize=10,c='darkviolet',linewidth=3,
               label=r'$L/h = 32$')
ax1.legend(loc=3,fontsize='20')
ax1.set_xlim((8,2000))
ax1.set_ylim((0.00002,1))
ax1.set_xscale("log", nonposx='clip')
ax1.set_yscale("log", nonposy='clip')
ax1.set_xlabel(r'$T/d$ (fixed $d$)',fontsize='20')
ax1.set_ylabel(r'$\epsilon_{\mathrm{L}^2,\mathbf{q}}$',fontsize='20')
ax1.tick_params(axis='both', which='major', labelsize='20')

ax1.text(200,0.4,r'$\mathbb{R}^{1+1}$, global, pol.1',fontsize=20)

#fig1.tight_layout()

savefig('DEL_evo1.pdf')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [2.03183901 2.00807832 2.00201788 2.00050454 2.00012633]
# /Users/jiaxin/lab/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['ylim']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# #### spatial domain fixed total time (convergence check)

# %%
# %pylab inline
import matplotlib.pyplot as plt

err_lv0 = array(matrix('5       0.0311556;\
10      0.022786;\
15      0.0227861;\
20      0.0227861;\
25      0.0227861;\
30      0.0227861;\
35      0.0227861;\
40      0.0227861;\
45      0.0227861;\
50      0.0227861;\
55      0.0227861;\
60      0.0227861;\
65      0.0227861;\
70      0.0227861;\
75      0.0227861;\
80      0.0227861;\
85      0.0227861;\
90      0.0227861;\
95      0.0227861;\
100     0.0227861;\
105     0.0227861;\
110     0.0227861;\
115     0.0227861;\
120     0.0227861;\
125     0.0227861;\
130     0.0227861;\
135     0.0227861;\
140     0.0227861;\
145     0.0227861;\
150     0.0227861;\
155     0.0227861;\
160     0.0227861;\
165     0.0227861;\
170     0.0227861;\
175     0.0227861;\
180     0.0227861;\
185     0.0227861;\
190     0.0227861;\
195     0.0227861'))

err_lv1 = array(matrix('5       0.0714132;\
10      0.0235725;\
15      0.00676244;\
20      0.00582054;\
25      0.00581554;\
30      0.00581554;\
35      0.00581554;\
40      0.00581554;\
45      0.00581554;\
50      0.00581554;\
55      0.00581554;\
60      0.00581554;\
65      0.00581554;\
70      0.00581554;\
75      0.00581554;\
80      0.00581554;\
85      0.00581554;\
90      0.00581554;\
95      0.00581554;\
100     0.00581554;\
105     0.00581554;\
110     0.00581554;\
115     0.00581554;\
120     0.00581554;\
125     0.00581554;\
130     0.00581554;\
135     0.00581554;\
140     0.00581554;\
145     0.00581554;\
150     0.00581554;\
155     0.00581554;\
160     0.00581554;\
165     0.00581554;\
170     0.00581554;\
175     0.00581554;\
180     0.00581554;\
185     0.00581554;\
190     0.00581554;\
195     0.00581554'))

err_lv2 = array(matrix('5       0.169111;\
10      0.0641526;\
15      0.0277212;\
20      0.0117835;\
25      0.00494228;\
30      0.00243778;\
35      0.00164688;\
40      0.00147989;\
45      0.00145723;\
50      0.00145503;\
55      0.00145487;\
60      0.00145486;\
65      0.00145486;\
70      0.00145486;\
75      0.00145486;\
80      0.00145486;\
85      0.00145486;\
90      0.00145486;\
95      0.00145486;\
100     0.00145486;\
105     0.00145486;\
110     0.00145486;\
115     0.00145486;\
120     0.00145486;\
125     0.00145486;\
130     0.00145486;\
135     0.00145486;\
140     0.00145486;\
145     0.00145486;\
150     0.00145486;\
155     0.00145486;\
160     0.00145486;\
165     0.00145486;\
170     0.00145486;\
175     0.00145486;\
180     0.00145486;\
185     0.00145486;\
190     0.00145486;\
195     0.00145486'))

err_lv3 = array(matrix('5       0.238983;\
10      0.122573;\
15      0.0729668;\
20      0.0458264;\
25      0.0296705;\
30      0.0194231;\
35      0.0127407;\
40      0.00831569;\
45      0.00537593;\
50      0.0034344;\
55      0.00216877;\
60      0.00136266;\
65      0.000869766;\
70      0.000590314;\
75      0.00045142;\
80      0.000393525;\
85      0.000373008;\
90      0.000366516;\
95      0.000364612;\
100     0.000364086;\
105     0.000363948;\
110     0.000363914;\
115     0.000363906;\
120     0.000363904;\
125     0.000363903;\
130     0.000363903;\
135     0.000363903;\
140     0.000363903;\
145     0.000363903;\
150     0.000363903;\
155     0.000363903;\
160     0.000363903;\
165     0.000363903;\
170     0.000363903;\
175     0.000363903;\
180     0.000363903;\
185     0.000363903;\
190     0.000363903;\
195     0.000363903'))

err_lv4 = array(matrix('5       0.283981;\
10      0.170498;\
15      0.118286;\
20      0.0870112;\
25      0.0662626;\
30      0.0515467;\
35      0.0406811;\
40      0.0324256;\
45      0.026023;\
50      0.0209806;\
55      0.0169637;\
60      0.0137362;\
65      0.0111269;\
70      0.00900813;\
75      0.0072831;\
80      0.00587667;\
85      0.00472972;\
90      0.00379507;\
95      0.00303464;\
100     0.00241741;\
105     0.00191792;\
110     0.00151519;\
115     0.00119186;\
120     0.00093353;\
125     0.000728303;\
130     0.000566337;\
135     0.000439538;\
140     0.000341283;\
145     0.000266182;\
150     0.000209864;\
155     0.000168752;\
160     0.000139825;\
165     0.000120399;\
170     0.000108026;\
175     0.000100548;\
180     9.62307e-05;\
185     9.38281e-05;\
190     9.25286e-05;\
195     9.18414e-05'))

e_1d_rg1 = array(matrix('0    0.0227861;\
1    0.00581554;\
2    0.00145486;\
3    0.000363903;\
4    9.11236e-05'))

print (2**(e_1d_rg1[:,1]+1))

fig1, ax1 = plt.subplots(figsize=(9,9))

l0 = ax1.plot((0,2000),(e_1d_rg1[0,1],e_1d_rg1[0,1]),color='grey',linestyle='--',linewidth=2)
l1 = ax1.plot((0,2000),(e_1d_rg1[1,1],e_1d_rg1[1,1]),color='grey',linestyle='--',linewidth=2)
l2 = ax1.plot((0,2000),(e_1d_rg1[2,1],e_1d_rg1[2,1]),color='grey',linestyle='--',linewidth=2)
l3 = ax1.plot((0,2000),(e_1d_rg1[3,1],e_1d_rg1[3,1]),color='grey',linestyle='--',linewidth=2)
l4 = ax1.plot((0,2000),(e_1d_rg1[4,1],e_1d_rg1[4,1]),color='grey',linestyle='--',linewidth=2)

c0 = ax1.plot (err_lv0[:,0],err_lv0[:,1],
               marker='X',markersize=10,c='steelblue',linewidth=3,
               label=r'$L/h = 2$')
c1 = ax1.plot (err_lv1[:,0],err_lv1[:,1],
               marker='o',markersize=10,c='firebrick',linewidth=3,
               label=r'$L/h = 4$')
c2 = ax1.plot (err_lv2[:,0],err_lv2[:,1],
               marker='s',markersize=10,c='darkseagreen',linewidth=3,
               label=r'$L/h = 8$')
c3 = ax1.plot (err_lv3[:,0],err_lv3[:,1],
               marker='d',markersize=10,c='darkorange',linewidth=3,
               label=r'$L/h = 16$')
c4 = ax1.plot (err_lv4[:,0],err_lv4[:,1],
               marker='*',markersize=10,c='darkviolet',linewidth=3,
               label=r'$L/h = 32$')

ax1.legend(loc=3,fontsize='20')
ax1.set_xlim((4.8,200))
ax1.set_ylim((0.00002,1))
ax1.set_xscale("log", nonposx='clip')
ax1.set_yscale("log", nonposy='clip')
ax1.set_xlabel(r'$T/d$ (fixed $T$)',fontsize='20')
ax1.set_ylabel(r'$\epsilon_{\mathrm{L}^2,\mathbf{q}}$',fontsize='20')
ax1.tick_params(axis='both', which='major', labelsize='20')

ax2 = ax1.twinx()

s = array(matrix('15      0.0227861;\
25      0.00581554;\
60      0.00145486;\
125     0.000363903'))
ax2.scatter (s[:,0],s[:,1],marker='X',s=200,c='black',label='saturation')

s = np.linspace(1,3000,100)
ax2.plot(s,4.5*s**(-2),linestyle='-.',linewidth=2,color='k',label=r'$d^{2}$ scaling')

ax2.set_yscale("log", nonposy='clip')
ax2.set_ylim((0.00002,1))
ax2.legend(loc=1,fontsize='20')
plt.axis('off')

ax1.text(10,0.4,r'$\mathbb{R}^{1+1}$, global, pol.1',fontsize=20)

#fig1.tight_layout()

savefig('DEL_conv1.pdf')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [2.03183901 2.00807832 2.00201788 2.00050454 2.00012633]

# %% [markdown]
# #### spectral domain fixed time difference (evolution check)

# %%
# %pylab inline
import matplotlib.pyplot as plt

# SPECTRAL
threads = linspace(1,20,num=20)

err_lv0 = array(matrix('10	1.14649;\
60	0.631011;\
110	0.348424;\
160	0.19371;\
210	0.109309;\
260	0.0637343;\
310	0.0397627;\
360	0.0278135;\
410	0.0222769;\
460	0.0198365;\
510	0.0187541;\
560	0.0182504;\
610	0.0180022;\
660	0.0178741;\
710	0.017806;\
760	0.0177691;\
810	0.0177489;\
860	0.0177379;\
910	0.0177318;\
960	0.0177285;\
1010	0.0177267;\
1060	0.0177257;\
1110	0.0177251;\
1160	0.0177249;\
1210	0.0177247;\
1260	0.0177246;\
1310	0.0177246;\
1360	0.0177245;\
1410	0.0177245;\
1460	0.0177245;\
1510	0.0177245;\
1560	0.0177245;\
1610	0.0177245;\
1660	0.0177245;\
1710	0.0177245;\
1760	0.0177245;\
1810	0.0177245;\
1860	0.0177245;\
1910	0.0177245;\
1960	0.0177245;\
2010	0.0177245;\
2060	0.0177245'))

err_lv1 = array(matrix('10	1.34678;\
60	0.849069;\
110	0.504886;\
160	0.300294;\
210	0.178753;\
260	0.106584;\
310	0.0637764;\
360	0.0384475;\
410	0.023551;\
460	0.0149164;\
510	0.010068;\
560	0.00749517;\
610	0.00622353;\
660	0.00562705;\
710	0.00534955;\
760	0.00521639;\
810	0.00514924;\
860	0.00511361;\
910	0.00509391;\
960	0.00508266;\
1010	0.00507611;\
1060	0.00507224;\
1110	0.00506993;\
1160	0.00506855;\
1210	0.00506773;\
1260	0.00506723;\
1310	0.00506693;\
1360	0.00506676;\
1410	0.00506665;\
1460	0.00506659;\
1510	0.00506655;\
1560	0.00506653;\
1610	0.00506651;\
1660	0.00506651;\
1710	0.0050665;\
1760	0.0050665;\
1810	0.0050665;\
1860	0.0050665;\
1910	0.0050665;\
l0 = ax1.plot((0,2000),(e_1d_rg1[0,1],e_1d_rg1[0,1]),color='grey',linestyle='--',linewidth=2)
l1 = ax1.plot((0,2000),(e_1d_rg1[1,1],e_1d_rg1[1,1]),color='grey',linestyle='--',linewidth=2)
l2 = ax1.plot((0,2000),(e_1d_rg1[2,1],e_1d_rg1[2,1]),color='grey',linestyle='--',linewidth=2)
l3 = ax1.plot((0,2000),(e_1d_rg1[3,1],e_1d_rg1[3,1]),color='grey',linestyle='--',linewidth=2)
l4 = ax1.plot((0,2000),(e_1d_rg1[4,1],e_1d_rg1[4,1]),color='grey',linestyle='--',linewidth=2)

c0 = ax1.plot (err_lv0[:,0],err_lv0[:,1],
               marker='X',markersize=10,c='steelblue',linewidth=3,
               label=r'$L/h = 2$')
c1 = ax1.plot (err_lv1[:,0],err_lv1[:,1],
               marker='o',markersize=10,c='firebrick',linewidth=3,
               label=r'$L/h = 4$')
c2 = ax1.plot (err_lv2[:,0],err_lv2[:,1],
               marker='s',markersize=10,c='darkseagreen',linewidth=3,
               label=r'$L/h = 8$')
c3 = ax1.plot (err_lv3[:,0],err_lv3[:,1],
               marker='d',markersize=10,c='darkorange',linewidth=3,
               label=r'$L/h = 16$')
c4 = ax1.plot (err_lv4[:,0],err_lv4[:,1],
               marker='*',markersize=10,c='darkviolet',linewidth=3,
               label=r'$L/h = 32$')
ax1.legend(loc=3,fontsize='20')
ax1.set_xlim((8,2000))
ax1.set_ylim((0.00005,2))
ax1.set_xscale("log", nonposx='clip')
ax1.set_yscale("log", nonposy='clip')
ax1.set_xlabel(r'$T/d$ (fixed $d$)',fontsize='20')
ax1.set_ylabel(r'$\epsilon_{\mathrm{L}^2,\mathbf{x}}$',fontsize='20')
ax1.tick_params(axis='both', which='major', labelsize='20')

ax1.text(200,0.8,r'$\mathbb{R}^{1+1}$, global, pol.1',fontsize=20)

#fig1.tight_layout()

savefig('DEL_evo2.pdf')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [2.02472293 2.00703601 2.00182303 2.00046199 2.0001163 ]

# %% [markdown]
# #### spectral domain fixed totoal time (convergence check)

# %%
# %pylab inline
import matplotlib.pyplot as plt

err_lv0 = array(matrix('5       0.0743264;\
10      0.0177101;\
15      0.0177245;\
20      0.0177245;\
25      0.0177245;\
30      0.0177245;\
35      0.0177245;\
40      0.0177245;\
45      0.0177245;\
50      0.0177245;\
55      0.0177245;\
60      0.0177245;\
65      0.0177245;\
70      0.0177245;\
75      0.0177245;\
80      0.0177245;\
85      0.0177245;\
90      0.0177245;\
95      0.0177245;\
100     0.0177245;\
105     0.0177245;\
110     0.0177245;\
115     0.0177245;\
120     0.0177245;\
125     0.0177245;\
130     0.0177245;\
135     0.0177245;\
140     0.0177245;\
145     0.0177245;\
150     0.0177245;\
155     0.0177245;\
160     0.0177245;\
165     0.0177245;\
170     0.0177245;\
175     0.0177245;\
180     0.0177245;\
185     0.0177245;\
190     0.0177245;\
195     0.0177245'))

err_lv1 = array(matrix('5       0.171906;\
10      0.101484;\
15      0.0288556;\
155     8.38889e-05;\
160     8.38967e-05;\
165     8.3892e-05;\
170     8.38932e-05;\
175     8.38945e-05;\
180     8.38921e-05;\
185     8.38944e-05;\
190     8.38929e-05;\
195     8.38934e-05'))

e_1d_rg1 = array(matrix('0    0.0177245;\
1    0.0050665;\
2    0.00131444;\
3    0.000333218;\
4    8.38934e-05'))

print (2**(e_1d_rg1[:,1]+1))

fig1, ax1 = plt.subplots(figsize=(9,9))

l0 = ax1.plot((0,2000),(e_1d_rg1[0,1],e_1d_rg1[0,1]),color='grey',linestyle='--',linewidth=2)
l1 = ax1.plot((0,2000),(e_1d_rg1[1,1],e_1d_rg1[1,1]),color='grey',linestyle='--',linewidth=2)
l2 = ax1.plot((0,2000),(e_1d_rg1[2,1],e_1d_rg1[2,1]),color='grey',linestyle='--',linewidth=2)
l3 = ax1.plot((0,2000),(e_1d_rg1[3,1],e_1d_rg1[3,1]),color='grey',linestyle='--',linewidth=2)
l4 = ax1.plot((0,2000),(e_1d_rg1[4,1],e_1d_rg1[4,1]),color='grey',linestyle='--',linewidth=2)

c0 = ax1.plot (err_lv0[:,0],err_lv0[:,1],
               marker='X',markersize=10,c='steelblue',linewidth=3,
               label=r'$L/h = 2$')
c1 = ax1.plot (err_lv1[:,0],err_lv1[:,1],
               marker='o',markersize=10,c='firebrick',linewidth=3,
               label=r'$L/h = 4$')
c2 = ax1.plot (err_lv2[:,0],err_lv2[:,1],
               marker='s',markersize=10,c='darkseagreen',linewidth=3,
               label=r'$L/h = 8$')
c3 = ax1.plot (err_lv3[:,0],err_lv3[:,1],
               marker='d',markersize=10,c='darkorange',linewidth=3,
               label=r'$L/h = 16$')
c4 = ax1.plot (err_lv4[:,0],err_lv4[:,1],
               marker='*',markersize=10,c='darkviolet',linewidth=3,
               label=r'$L/h = 32$')

ax1.legend(loc=3,fontsize='20')
ax1.set_xlim((4.8,200))
ax1.set_ylim((0.00005,1))
ax1.set_xscale("log", nonposx='clip')
ax1.set_yscale("log", nonposy='clip')
ax1.set_xlabel(r'$T/d$ (fixed $T$)',fontsize='20')
ax1.set_ylabel(r'$\epsilon_{\mathrm{L}^2,\mathbf{x}}$',fontsize='20')
ax1.tick_params(axis='both', which='major', labelsize='20')

ax2 = ax1.twinx()

s = array(matrix('15      0.0177245;\
45      0.0050665;\
85      0.00131444;\
185     0.000333218;\
195     8.38934e-05'))
ax2.scatter (s[:,0],s[:,1],marker='X',s=200,c='black',label='saturation')

s = np.linspace(1,3000,100)
ax2.plot(s,0.6e+1*s**(-2),linestyle='-.',linewidth=2,color='k',label=r'$d^{2}$ scaling')

ax2.set_yscale("log", nonposy='clip')
ax2.set_ylim((0.00005,1))
ax2.legend(loc=1,fontsize='20')
plt.axis('off')

ax1.text(10,0.4,r'$\mathbb{R}^{1+1}$, global, pol.1',fontsize=20)

#fig1.tight_layout()

savefig('DEL_conv2.pdf')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [2.02472293 2.00703601 2.00182303 2.00046199 2.0001163 ]

# %% [markdown]
# ## execute the corresponding example and check if above figures can be recovered
